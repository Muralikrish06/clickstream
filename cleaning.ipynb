# %%
#CLICKSTREAM ANALYSIS.
#READ THE TEST AND TRAIN DATA.
import pandas as pd
import numpy as np
train=pd.read_csv("C:/Users/murkr/Downloads/train_data.csv")
test=pd.read_csv("C:/Users/murkr/Downloads/test_data.csv")
display(train)
display(test)
# Out:
#         year  month  day  order  country  session_id  page1_main_category  \
# 0       2008      6   22     21       29       15648                    3
# 1       2008      5   19      6       29       10018                    2
# 2       2008      7   15      2       29       19388                    3
# 3       2008      5    2      2       29        7181                    2
# 4       2008      6    9     16       29       13493                    2
# ...      ...    ...  ...    ...      ...         ...                  ...
# 132374  2008      7    4      3       29       17622                    4
# 132375  2008      6   19      9       29       15165                    3
# 132376  2008      7   15      4       29       19359                    1
# 132377  2008      7   28     16       29       21454                    3
# 132378  2008      7    6     17       29       17897                    2
#
#        page2_clothing_model  colour  location  model_photography  price  \
# ...

# %%
#MONTH MAPPER.
import pandas as pd
class MonthMapper:
    def __init__(self):
        self.month_map = {
            1: 'January',
            2: 'February',
            3: 'March',
            4: 'April',
            5: 'May',
            6: 'June',
            7: 'July',
            8: 'August',
            9: 'September',
            10: 'October',
            11: 'November',
            12: 'December'
        }
    def map_month(self, df):
        df['month'] = df['month'].map(self.month_map)
        return df

month_mapper = MonthMapper()
train = month_mapper.map_month(train)
display(train)
# Out:
#         year month  day  order  country  session_id  page1_main_category  \
# 0       2008  June   22     21       29       15648                    3
# 1       2008   May   19      6       29       10018                    2
# 2       2008  July   15      2       29       19388                    3
# 3       2008   May    2      2       29        7181                    2
# 4       2008  June    9     16       29       13493                    2
# ...      ...   ...  ...    ...      ...         ...                  ...
# 132374  2008  July    4      3       29       17622                    4
# 132375  2008  June   19      9       29       15165                    3
# 132376  2008  July   15      4       29       19359                    1
# 132377  2008  July   28     16       29       21454                    3
# 132378  2008  July    6     17       29       17897                    2
#
#        page2_clothing_model  colour  location  model_photography  price  \
# ...

# %%
#COUNTRY MAPPING.
import pandas as pd

class CountryMapper:
    def __init__(self):
        self.country_map = {
            "1": "Australia", "2": "Austria", "3": "Belgium", "4": "British Virgin Islands",
            "5": "Cayman Islands", "6": "Christmas Island", "7": "Croatia", "8": "Cyprus",
            "9": "Czech Republic", "10": "Denmark", "11": "Estonia", "12": "unidentified",
            "13": "Faroe Islands", "14": "Finland", "15": "France", "16": "Germany", "17": "Greece",
            "18": "Hungary", "19": "Iceland", "20": "India", "21": "Ireland", "22": "Italy",
            "23": "Latvia", "24": "Lithuania", "25": "Luxembourg", "26": "Mexico",
            "27": "Netherlands", "28": "Norway", "29": "Poland", "30": "Portugal", "31": "Romania",
            "32": "Russia", "33": "San Marion", "34": "Slovakia", "35": "Slovenia", "36": "Spain",
            "37": "Sweden", "38": "Switzerland", "39": "Ukraine", "40": "United Arab Emirates",
            "41": "United Kingdom", "42": "USA", "43": "biz (.biz)", "44": "com (.com)",
            "45": "int (.int)", "46": "net (.net)", "47": "org (*.org)"
        }

    def map_countries(self, df):
        df = df.copy()
        df['country'] = df['country'].astype(str)
        df['country'] = df['country'].replace(self.country_map)
        df['country'] = df['country'].replace('nan', 'unidentified')
        return df


# Initialize the mapper
mapper = CountryMapper()

# Map countries
train = mapper.map_countries(train)
#test = mapper.map_countries(test)

# Display the results
display(train)
# Out:
#         year month  day  order country  session_id  page1_main_category  \
# 0       2008  June   22     21  Poland       15648                    3
# 1       2008   May   19      6  Poland       10018                    2
# 2       2008  July   15      2  Poland       19388                    3
# 3       2008   May    2      2  Poland        7181                    2
# 4       2008  June    9     16  Poland       13493                    2
# ...      ...   ...  ...    ...     ...         ...                  ...
# 132374  2008  July    4      3  Poland       17622                    4
# 132375  2008  June   19      9  Poland       15165                    3
# 132376  2008  July   15      4  Poland       19359                    1
# 132377  2008  July   28     16  Poland       21454                    3
# 132378  2008  July    6     17  Poland       17897                    2
#
#        page2_clothing_model  colour  location  model_photography  price  \
# ...

# %%
#PAGE1 MAIN CATEFROY MAPPER.
import pandas as pd

class Page1Mapper:
    def __init__(self):
        self.page1_map = {
            "1": "trousers",
            "2": "skirts",
            "3": "blouses",
            "4": "sale"
        }
    
    def map_page1(self, df):
        df = df.copy()
        df['page1_main_category'] = df['page1_main_category'].astype(str)
        df['page1_main_category'] = df['page1_main_category'].replace(self.page1_map)
        return df

# Read your data


# Now apply the Page1Mapper
page1_mapper = Page1Mapper()
train = page1_mapper.map_page1(train)

# Display the updated train data
display(train)
# Out:
#         year month  day  order country  session_id page1_main_category  \
# 0       2008  June   22     21  Poland       15648             blouses
# 1       2008   May   19      6  Poland       10018              skirts
# 2       2008  July   15      2  Poland       19388             blouses
# 3       2008   May    2      2  Poland        7181              skirts
# 4       2008  June    9     16  Poland       13493              skirts
# ...      ...   ...  ...    ...     ...         ...                 ...
# 132374  2008  July    4      3  Poland       17622                sale
# 132375  2008  June   19      9  Poland       15165             blouses
# 132376  2008  July   15      4  Poland       19359            trousers
# 132377  2008  July   28     16  Poland       21454             blouses
# 132378  2008  July    6     17  Poland       17897              skirts
#
#        page2_clothing_model  colour  location  model_photography  price  \
# ...

# %%
import pandas as pd

class ColourMapper:
    def __init__(self):
        self.colour_map = {
            "1": "beige",
            "2": "black",
            "3": "blue",
            "4": "brown",
            "5": "burgundy",
            "6": "gray",
            "7": "green",
            "8": "navy blue",
            "9": "of many colors",
            "10": "olive",
            "11": "pink",
            "12": "red",
            "13": "violet",
            "14": "white"
        }

    def map_colours(self, df):
        df = df.copy()
        df['colour'] = df['colour'].astype(str)
        df['colour'] = df['colour'].replace(self.colour_map)
        return df

# Initialize the mapper
colour_mapper = ColourMapper()

# Map colours
train = colour_mapper.map_colours(train)

# Display the results
display(train)
# Out:
#         year month  day  order country  session_id page1_main_category  \
# 0       2008  June   22     21  Poland       15648             blouses
# 1       2008   May   19      6  Poland       10018              skirts
# 2       2008  July   15      2  Poland       19388             blouses
# 3       2008   May    2      2  Poland        7181              skirts
# 4       2008  June    9     16  Poland       13493              skirts
# ...      ...   ...  ...    ...     ...         ...                 ...
# 132374  2008  July    4      3  Poland       17622                sale
# 132375  2008  June   19      9  Poland       15165             blouses
# 132376  2008  July   15      4  Poland       19359            trousers
# 132377  2008  July   28     16  Poland       21454             blouses
# 132378  2008  July    6     17  Poland       17897              skirts
#
#        page2_clothing_model          colour  location  model_photography  \
# ...

# %%
import pandas as pd

class LocationMapper:
    def __init__(self):
        self.location_map = {
            "1": "top left",
            "2": "top in the middle",
            "3": "top right",
            "4": "bottom left",
            "5": "bottom in the middle",
            "6": "bottom right"
        }

    def map_locations(self, df):
        df = df.copy()
        df['location'] = df['location'].astype(str)
        df['location'] = df['location'].replace(self.location_map)
        return df

# Initialize the mapper
location_mapper = LocationMapper()

# Map locations
train = location_mapper.map_locations(train)

# Display the results
display(train)
# Out:
#         year month  day  order country  session_id page1_main_category  \
# 0       2008  June   22     21  Poland       15648             blouses
# 1       2008   May   19      6  Poland       10018              skirts
# 2       2008  July   15      2  Poland       19388             blouses
# 3       2008   May    2      2  Poland        7181              skirts
# 4       2008  June    9     16  Poland       13493              skirts
# ...      ...   ...  ...    ...     ...         ...                 ...
# 132374  2008  July    4      3  Poland       17622                sale
# 132375  2008  June   19      9  Poland       15165             blouses
# 132376  2008  July   15      4  Poland       19359            trousers
# 132377  2008  July   28     16  Poland       21454             blouses
# 132378  2008  July    6     17  Poland       17897              skirts
#
#        page2_clothing_model          colour              location  \
# ...

# %%
#MODEL_PHOTO MAPPER.
import pandas as pd

class ModelPhotoMapper:
    def __init__(self):
        self.model_map = {
            "1": "En face",
            "2": "Profile"
        }

    def map_model_photo(self, df):
        df = df.copy()
        df['model_photography'] = df['model_photography'].astype(str)
        df['model_photography'] = df['model_photography'].replace(self.model_map)
        return df

# Initialize the mapper
model_photo_mapper = ModelPhotoMapper()

# Map model_photography
train = model_photo_mapper.map_model_photo(train)

# Display the results
display(train)
# Out:
#         year month  day  order country  session_id page1_main_category  \
# 0       2008  June   22     21  Poland       15648             blouses
# 1       2008   May   19      6  Poland       10018              skirts
# 2       2008  July   15      2  Poland       19388             blouses
# 3       2008   May    2      2  Poland        7181              skirts
# 4       2008  June    9     16  Poland       13493              skirts
# ...      ...   ...  ...    ...     ...         ...                 ...
# 132374  2008  July    4      3  Poland       17622                sale
# 132375  2008  June   19      9  Poland       15165             blouses
# 132376  2008  July   15      4  Poland       19359            trousers
# 132377  2008  July   28     16  Poland       21454             blouses
# 132378  2008  July    6     17  Poland       17897              skirts
#
#        page2_clothing_model          colour              location  \
# ...

# %%
#SAve the data to csv and display it.
train.to_csv("C:/Users/murkr/Downloads/train_data_mapped.csv", index=False)
train_mapped = pd.read_csv("C:/Users/murkr/Downloads/train_data_mapped.csv")
display(train_mapped)
# Out:
#         year month  day  order country  session_id page1_main_category  \
# 0       2008  June   22     21  Poland       15648             blouses
# 1       2008   May   19      6  Poland       10018              skirts
# 2       2008  July   15      2  Poland       19388             blouses
# 3       2008   May    2      2  Poland        7181              skirts
# 4       2008  June    9     16  Poland       13493              skirts
# ...      ...   ...  ...    ...     ...         ...                 ...
# 132374  2008  July    4      3  Poland       17622                sale
# 132375  2008  June   19      9  Poland       15165             blouses
# 132376  2008  July   15      4  Poland       19359            trousers
# 132377  2008  July   28     16  Poland       21454             blouses
# 132378  2008  July    6     17  Poland       17897              skirts
#
#        page2_clothing_model          colour              location  \
# ...

# %%
import matplotlib.pyplot as plt

# Count clicks by country name
country_clicks = train['country'].value_counts()

# Plot
plt.figure(figsize=(12, 6))
country_clicks.plot(kind='bar', color='skyblue', edgecolor='black')
plt.title('Number of Clicks by Country', fontsize=16)
plt.xlabel('Country', fontsize=14)
plt.ylabel('Number of Clicks', fontsize=14)
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
#Flexibility in buying for each country and visualize it.
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
df1=train_mapped.groupby(['country','page1_main_category']).size().reset_index(name='counts')
plt.figure(figsize=(12, 6))
sns.barplot(x='country', y='counts', hue='page1_main_category', data=df1, palette='viridis')
plt.title('Flexibility in Buying for Each Country', fontsize=16)
plt.xlabel('Country', fontsize=14)
plt.ylabel('Counts', fontsize=14)
plt.xticks(rotation=45, ha='right')
plt.legend(title='Page 1 Main Category')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
#CUSTOMER BUY FROM EACH PAGE AND VISUALIZE IT.
import matplotlib.pyplot as plt
df2=train_mapped.groupby(['page1_main_category','page']).size().reset_index(name='counts')
plt.figure(figsize=(12, 6))
import seaborn as sns
sns.barplot(x='page1_main_category', y='counts',hue='page' ,data=df2, palette='viridis')
plt.title('Customer Buy from Each Page', fontsize=16)
plt.xlabel('Page 1 Main Category', fontsize=14)
plt.ylabel('Counts', fontsize=14)
plt.xticks(rotation=45, ha='right')
plt.legend(title='Page 2 Main Category')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
#MOST ATTRACTIVE location and colour and visualize it.

import matplotlib.pyplot as plt
import seaborn as sns
df3=train_mapped.groupby(['location','colour']).size().reset_index(name='counts')
plt.figure(figsize=(12, 6))
sns.barplot(x='location', y='counts', hue='colour', data=df3, palette='viridis')
plt.title('Most Attractive Location and Colour', fontsize=16)
plt.xlabel('Location', fontsize=14)
plt.ylabel('Counts', fontsize=14)
plt.xticks(rotation=45, ha='right')
plt.legend(title='Colour')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
#SELLING PRODUCTS BY COLOUR.
import matplotlib.pyplot as plt
import seaborn as sns
df4=train_mapped.groupby(['colour','page1_main_category']).size().reset_index(name='counts')
plt.figure(figsize=(12, 6))
sns.barplot(x='colour', y='counts', hue='page1_main_category', data=df4, palette='viridis')
plt.title('Selling Products by Colour', fontsize=16)
plt.xlabel('Colour', fontsize=14)
plt.ylabel('Counts', fontsize=14)
plt.xticks(rotation=45, ha='right')
plt.legend(title='Page 1 Main Category')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
#MODELPHOTOGRAPHY AND LOCATION.
import matplotlib.pyplot as plt
import seaborn as sns
df5=train_mapped.groupby(['model_photography','location']).size().reset_index(name='counts')
plt.figure(figsize=(12, 6))
sns.barplot(x='model_photography', y='counts', hue='location', data=df5, palette='viridis')
plt.title('Model Photography and Location', fontsize=16)
plt.xlabel('Model Photography', fontsize=14)
plt.ylabel('Counts', fontsize=14)
plt.xticks(rotation=45, ha='right')
plt.legend(title='Location')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
#Relatioship btn month and page1_main_category.
import matplotlib.pyplot as plt
import seaborn as sns
df6=train_mapped.groupby(['month','page1_main_category']).size().reset_index(name='counts')
plt.figure(figsize=(12, 6))
sns.barplot(x='month', y='counts', hue='page1_main_category', data=df6, palette='viridis')
plt.title('Relationship Between Month and Page 1 Main Category', fontsize=16)
plt.xlabel('Month', fontsize=14)
plt.ylabel('Counts', fontsize=14)
plt.xticks(rotation=45, ha='right')
plt.legend(title='Page 1 Main Category')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
import pandas as pd

class LabelEncoder:
    def __init__(self):
        self.label_map = {}
        self.inverse_label_map = {}

    def fit(self, df, column):
        # Generate label mapping for a column
        unique_values = df[column].unique()
        for index, value in enumerate(unique_values):
            self.label_map[value] = index
            self.inverse_label_map[index] = value

    def transform(self, df, column):
        # Transform the column using the label_map
        df[column] = df[column].map(self.label_map)
        return df

    def inverse_transform(self, df, column):
        # Inverse transform the column using inverse_label_map
        df[column] = df[column].map(self.inverse_label_map)
        return df
    
# Initialize the label encoder
label_encoder = LabelEncoder()

# Fit the encoder on the 'train' dataset, only on training columns
label_encoder.fit(train, 'country')
label_encoder.fit(train, 'page1_main_category')
label_encoder.fit(train, 'colour')
label_encoder.fit(train, 'location')
label_encoder.fit(train, 'model_photography')
label_encoder.fit(train, 'month')
label_encoder.fit(train, 'page2_clothing_model')

# Transform the 'train' dataset using the fitted label maps
train = label_encoder.transform(train, 'country')
train = label_encoder.transform(train, 'page1_main_category')
train = label_encoder.transform(train, 'colour')
train = label_encoder.transform(train, 'location')
train = label_encoder.transform(train, 'model_photography')
train = label_encoder.transform(train, 'month')
train = label_encoder.transform(train, 'page2_clothing_model')

# Save the encoded train data to CSV
train.to_csv("C:/Users/murkr/Downloads/train_data_encoded.csv", index=False)

# Now load the encoded data and inspect it
train_encoded = pd.read_csv("C:/Users/murkr/Downloads/train_data_encoded.csv")
display(train_encoded)
# Out:
#         year  month  day  order  country  session_id  page1_main_category  \
# 0       2008      0   22     21        0       15648                    0
# 1       2008      1   19      6        0       10018                    1
# 2       2008      2   15      2        0       19388                    0
# 3       2008      1    2      2        0        7181                    1
# 4       2008      0    9     16        0       13493                    1
# ...      ...    ...  ...    ...      ...         ...                  ...
# 132374  2008      2    4      3        0       17622                    3
# 132375  2008      0   19      9        0       15165                    0
# 132376  2008      2   15      4        0       19359                    2
# 132377  2008      2   28     16        0       21454                    0
# 132378  2008      2    6     17        0       17897                    1
#
#         page2_clothing_model  colour  location  model_photography  price  \
# ...

# %%
import pandas as pd

class DataPreprocessor:
    def __init__(self):
        # Assuming that the mappers (MonthMapper, CountryMapper, etc.) are correctly implemented
        self.month_mapper = MonthMapper()
        self.country_mapper = CountryMapper()
        self.page1_mapper = Page1Mapper()
        self.colour_mapper = ColourMapper()
        self.location_mapper = LocationMapper()
        self.model_photo_mapper = ModelPhotoMapper()
        self.label_encoder = LabelEncoder()

    def preprocess(self, df, is_train=False):
        df = df.copy()
        
        # Apply mappers (replace this with your actual mapping classes)
        df = self.month_mapper.map_month(df)
        df = self.country_mapper.map_countries(df)
        df = self.page1_mapper.map_page1(df)
        df = self.colour_mapper.map_colours(df)
        df = self.location_mapper.map_locations(df)
        df = self.model_photo_mapper.map_model_photo(df)
        
        # Fit the label encoder only on the training data
        if is_train:
            self.label_encoder.fit(df, 'country')
            self.label_encoder.fit(df, 'page1_main_category')
            self.label_encoder.fit(df, 'colour')
            self.label_encoder.fit(df, 'location')
            self.label_encoder.fit(df, 'model_photography')
            self.label_encoder.fit(df, 'month')
            self.label_encoder.fit(df, 'page2_clothing_model')
        
        # Apply the label encoder transformation to both train and test data
        df = self.label_encoder.transform(df, 'country')
        df = self.label_encoder.transform(df, 'page1_main_category')
        df = self.label_encoder.transform(df, 'colour')
        df = self.label_encoder.transform(df, 'location')
        df = self.label_encoder.transform(df, 'model_photography')
        df = self.label_encoder.transform(df, 'month')
        df = self.label_encoder.transform(df, 'page2_clothing_model')

        return df

# Initialize the preprocessor
preprocessor = DataPreprocessor()

# For training data, we fit and transform
train = pd.read_csv("C:/Users/murkr/Downloads/train_data.csv")
train = preprocessor.preprocess(train, is_train=True)

# For test data, we only transform (using the encoder fitted on the train data)
test = pd.read_csv("C:/Users/murkr/Downloads/test_data.csv")
test_encoded = preprocessor.preprocess(test, is_train=False)

# Display the preprocessed test data
display(test_encoded)

# Save the preprocessed data to CSV
train.to_csv("C:/Users/murkr/Downloads/train_data_preprocessed.csv", index=False)
test_encoded.to_csv("C:/Users/murkr/Downloads/test_data_preprocessed.csv", index=False)
# Out:
#        year  month  day  order  country  session_id  page1_main_category  \
# 0      2008      4   22      4      0.0        5279                    3
# 1      2008      1   19      1      0.0       10059                    2
# 2      2008      4   11     10      0.0        2919                    3
# 3      2008      4   28      3     17.0        6304                    1
# 4      2008      1   26      1      0.0       11266                    2
# ...     ...    ...  ...    ...      ...         ...                  ...
# 33090  2008      1   13      1      0.0        8885                    2
# 33091  2008      4   14      3      0.0        3546                    2
# 33092  2008      0   13     37      0.0       14336                    1
# 33093  2008      1   23     16      0.0       10786                    0
# 33094  2008      4   19     17      3.0        4644                    0
#
#        page2_clothing_model  colour  location  model_photography  price  \
# ...

# %%
# Load the preprocessed data and inspect it
train_preprocessed = pd.read_csv("C:/Users/murkr/Downloads/train_data_preprocessed.csv")
test_preprocessed = pd.read_csv("C:/Users/murkr/Downloads/test_data_preprocessed.csv")
display(train_preprocessed)
display(test_preprocessed)
# Out:
#         year  month  day  order  country  session_id  page1_main_category  \
# 0       2008      0   22     21        0       15648                    0
# 1       2008      1   19      6        0       10018                    1
# 2       2008      2   15      2        0       19388                    0
# 3       2008      1    2      2        0        7181                    1
# 4       2008      0    9     16        0       13493                    1
# ...      ...    ...  ...    ...      ...         ...                  ...
# 132374  2008      2    4      3        0       17622                    3
# 132375  2008      0   19      9        0       15165                    0
# 132376  2008      2   15      4        0       19359                    2
# 132377  2008      2   28     16        0       21454                    0
# 132378  2008      2    6     17        0       17897                    1
#
#         page2_clothing_model  colour  location  model_photography  price  \
# ...

# %%
#CORELATION MATRIX.
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Load the preprocessed data
train_preprocessed = pd.read_csv("C:/Users/murkr/Downloads/train_data_preprocessed.csv")

# Calculate the correlation matrix
correlation_matrix = train_preprocessed.corr()

# Visualize the correlation matrix using a heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix', fontsize=16)
plt.tight_layout()
plt.show()

# %%
train_preprocessed.describe()
# Out:
#            year          month            day          order        country  \
# count  132379.0  132379.000000  132379.000000  132379.000000  132379.000000
# mean     2008.0       2.064096      14.507671       9.811314       0.728741
# std         0.0       1.498303       8.829106      13.458937       2.866223
# min      2008.0       0.000000       1.000000       1.000000       0.000000
# 25%      2008.0       1.000000       7.000000       2.000000       0.000000
# 50%      2008.0       2.000000      14.000000       6.000000       0.000000
# 75%      2008.0       4.000000      22.000000      12.000000       0.000000
# max      2008.0       4.000000      31.000000     195.000000      45.000000
#
#           session_id  page1_main_category  page2_clothing_model  \
# count  132379.000000        132379.000000         132379.000000
# mean    12038.722063             1.536097             84.482969
# std      7012.460866             1.088106             55.945638
# ...

# %%
train_preprocessed = pd.read_csv("C:/Users/murkr/Downloads/train_data_preprocessed.csv")
test_preprocessed = pd.read_csv("C:/Users/murkr/Downloads/test_data_preprocessed.csv")

display(train_preprocessed)
display(test_preprocessed)
# Out:
#         year  month  day  order  country  session_id  page1_main_category  \
# 0       2008      0   22     21        0       15648                    0
# 1       2008      1   19      6        0       10018                    1
# 2       2008      2   15      2        0       19388                    0
# 3       2008      1    2      2        0        7181                    1
# 4       2008      0    9     16        0       13493                    1
# ...      ...    ...  ...    ...      ...         ...                  ...
# 132374  2008      2    4      3        0       17622                    3
# 132375  2008      0   19      9        0       15165                    0
# 132376  2008      2   15      4        0       19359                    2
# 132377  2008      2   28     16        0       21454                    0
# 132378  2008      2    6     17        0       17897                    1
#
#         page2_clothing_model  colour  location  model_photography  price  \
# ...

# %%
train_preprocessed.isnull().sum()
# Out:
# year                    0
# month                   0
# day                     0
# order                   0
# country                 0
# session_id              0
# page1_main_category     0
# page2_clothing_model    0
# colour                  0
# location                0
# model_photography       0
# price                   0
# price_2                 0
# page                    0
# dtype: int64

# %%
test_preprocessed.isnull().sum()
# Out:
# year                    0
# month                   0
# day                     0
# order                   0
# country                 1
# session_id              0
# page1_main_category     0
# page2_clothing_model    1
# colour                  0
# location                0
# model_photography       0
# price                   0
# price_2                 0
# page                    0
# dtype: int64

# %%
test_preprocessed = test_preprocessed.dropna()

# %%
#AFTER REMOVE THE NULL VALUES make a new csv file.
test_preprocessed.to_csv("C:/Users/murkr/Downloads/test_data_preprocessed.csv", index=False)
test_preprocessed_csv = pd.read_csv("C:/Users/murkr/Downloads/test_data_preprocessed.csv")
display(test_preprocessed_csv   )
# Out:
#        year  month  day  order  country  session_id  page1_main_category  \
# 0      2008      4   22      4      0.0        5279                    3
# 1      2008      1   19      1      0.0       10059                    2
# 2      2008      4   11     10      0.0        2919                    3
# 3      2008      4   28      3     17.0        6304                    1
# 4      2008      1   26      1      0.0       11266                    2
# ...     ...    ...  ...    ...      ...         ...                  ...
# 33088  2008      1   13      1      0.0        8885                    2
# 33089  2008      4   14      3      0.0        3546                    2
# 33090  2008      0   13     37      0.0       14336                    1
# 33091  2008      1   23     16      0.0       10786                    0
# 33092  2008      4   19     17      3.0        4644                    0
#
#        page2_clothing_model  colour  location  model_photography  price  \
# ...

# %%
test_preprocessed['page'].value_counts()
# Out:
# page
# 1    18815
# 2     8153
# 3     3831
# 4     1751
# 5      543
# Name: count, dtype: int64

# %%
test_preprocessed_csv.isnull().sum()
# Out:
# year                    0
# month                   0
# day                     0
# order                   0
# country                 0
# session_id              0
# page1_main_category     0
# page2_clothing_model    0
# colour                  0
# location                0
# model_photography       0
# price                   0
# price_2                 0
# page                    0
# dtype: int64

# %%
#DROP THE UNNECESSARY COLUMNS in the traim and test data.
train_preprocessed_csv = train_preprocessed.drop(columns=['year', 'day', 'order', 'session_id'])
test_preprocessed_csv = test_preprocessed_csv.drop(columns=['year', 'day', 'order','session_id'])
# Save the cleaned test data to CSV
train_preprocessed_csv.to_csv("C:/Users/murkr/Downloads/train_data_cleaned.csv", index=False)
test_preprocessed_csv.to_csv("C:/Users/murkr/Downloads/test_data_cleaned.csv", index=False)
# Load the cleaned test data and inspect it
train_cleaned = pd.read_csv("C:/Users/murkr/Downloads/train_data_cleaned.csv")
test_cleaned = pd.read_csv("C:/Users/murkr/Downloads/test_data_cleaned.csv")
display(train_cleaned)
display(test_cleaned)
# Out:
#         month  country  page1_main_category  page2_clothing_model  colour  \
# 0           0        0                    0                     0       0
# 1           1        0                    1                     1       0
# 2           2        0                    0                     2       1
# 3           1        0                    1                     3       2
# 4           0        0                    1                     4       1
# ...       ...      ...                  ...                   ...     ...
# 132374      2        0                    3                   152       2
# 132375      0        0                    0                    17       6
# 132376      2        0                    2                    86       5
# 132377      2        0                    0                   124       1
# 132378      2        0                    1                   117       8
#
#         location  model_photography  price  price_2  page
# ...
